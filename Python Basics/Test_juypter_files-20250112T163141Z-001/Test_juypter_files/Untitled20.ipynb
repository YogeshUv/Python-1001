# %%
update_columns = '''store_nbr                        
,store_name                     
,store_status                   
,store_bill_to_flag             
,store_ship_to_flag             
,acct_id                        
,acct_nbr                       
,acct_name                      
,acct_status                    
,acct_cust_class_code           
,acct_creation_date             
,chain_nbr                      
,chain_name                     
,chain_short_name               
,chain_inactive_date            
,start_cust_nbr                 
,strt_cust_nbr2                 
,end_cust_nbr                   
,end_cust_nbr2                  
,private_label_offset           
,sub_auth_offst                 
,ad_start_day_of_week           
,company_code                   
,hq_cust_nbr                    
,division_nbr                   
,division_name                  
,ebs_gl_cust_group_nbr          
,ebs_gl_cust_group_name         
,store_group_nbr                
,store_group_name               
,group_buy_nbr                  
,store_creation_date            
,store_inactive_date            
,store_last_update_date         
,location_id                    
,store_address1                 
,store_address2                 
,store_address3                 
,store_address4                 
,store_city                     
,store_postal_code              
,store_state                    
,store_province                 
,store_county                   
,store_country                  
,store_telephone_nbr            
,cust_store_nbr                 
,cust_acct_profile_id           
,pay_terms                      
,pay_term_desc                  
,pay_term_start_date            
,pay_term_end_date              
,collector_name                 
,statement_cycle_name           
,alt_cust_nbr                   
,base_cust_nbr                  
,cust_statement_format          
,paca_flag                      
,tobacco_billable_flag          
,tobacco_rebate                 
,zone_nbr                       
,military_dodaac                
,sales_representative           
,request_id                     
,last_update_date               
,last_updated_by                
,last_update_login              
,bill_to_store_nbr              
,bill_to_store_name             
,primary_contact_name           
,primary_contact_phone_nbr      
,primary_contact_email_addr     
,customer_group                 
,store_group                    
,finance_charges                
,interest_rate                  
,payment_grace_days             
,interest_period_days           
,statement_address1             
,statement_city                 
,statement_state                
,statement_zip                  
,finance_charge_effective_date  
,summary_stmt_format            
,delinquent_start_date          
,ar_segment_group               
,ar_group_name                  
,imported_source                
,remittance_addr                
,statement_tolrnce              
,invoice_tolrnce                
,sales_rep                      
,risk_tier                      
,gs_retail_acctng_report        
,statement_level                
,related_cust_lockbox_applly    
,send_ach_notiftn               
,stock_name                     
,multi_store                    
,eft                            
,pickup_day                     
,pay_due_day                    
,credit_hold                    
,payment_terms                  
,credit_group                   
,blank_check_customer           
,ad_plan_group                  
,awi_party_site_id              
,awi_multi_store_nbr            
,patronage_nbr                  
,print_statements               
,statement_instructions         
,send_to_awi_cdh_flg            
,cm_billing_cycle               
,cm_terms                       
,cm_np_xfer_flag                
,cm_print_stmt                  
,cm_ret_acct_stmt               
,cm_stmt_copies                 
,cm_group_code                  
,cm_payment_method              
,cm_stmt_labels                 
,cm_payment_due_days            
,cm_sub_store                   
,cm_cust_xref_no                
,stmt_adj_group_code            
,psuedoephedrine_flag           
,call_for_customer              
,cigarette_license              
,small_pack                     
,cigarette_validation           
,awi_cdh_customer_class         
,gas_rewards                    
,miles                          
,print_stmts                    
,awi_cdh_rack_service           
,retail_type                    
,tax_exempt                     
,adv_flag_7                     
,adv_flag6                      
,bb_ad_plan                     
,ad_comments                    
,adv_flag5                      
,confo_ad_plan                  
,default_trip                   
,catalog10                      
,awi_print_bulletin             
,awi_sign_kit                   
,surveys                        
,adv_flag8                      
,awi_ad_offset                  
,agne_customer                  
,confo                          
,hba_gm_flag                    
,hba_gm_disc_overide            
,hba_gm_disc                    
,item_allowance                 
,cod                            
,serv_charge                    
,single_pick                    
,awi_customer_type              
,multi_store_number             
,eight_week_bb                  
,bb_mod_program                 
,kpc_end                        
,kpc_retail_zone                
,kpc_start                      
,awi_product                    
,specialty_foods                
,d_cost_plus_bracket_flag       
,d_cost_plus_bracket_number     
,d_merchandiser                 
,d_pricing_flag                 
,d_salesman                     
,d_skid_rounding_flag           
,sy_cost_plus_bracket_flag      
,sy_cost_plus_bracket_number    
,sy_merchandiser                
,sy_pricing_flag                
,sy_salesman                    
,sy_skid_rounding_flag          
,m_cost_plus_bracket_flag       
,m_cost_plus_bracket_number     
,m_merchandiser                 
,m_pricing_flag                 
,m_salesman                     
,m_skid_rounding_flag           
,p_cost_plus_bracket_flag       
,p_cost_plus_bracket_number     
,p_merchandiser                 
,p_pricing_flag                 
,p_salesman                     
,p_skid_rounding_flag           
,gm_cost_plus_bracket_flag      
,gm_cost_plus_bracket_number    
,gm_merchandiser                
,gm_pricing_flag                
,gm_salesman                    
,gm_skid_rounding_flag          
,c_cost_plus_bracket_flag       
,c_cost_plus_bracket_number     
,c_merchandiser                 
,c_pricing_flag                 
,c_salesman                     
,c_skid_rounding_flag           
,f_cost_plus_bracket_flag       
,f_cost_plus_bracket_number     
,f_merchandiser                 
,f_pricing_flag                 
,f_salesman                     
,f_skid_rounding_flag           
,rg_cost_plus_bracket_flag      
,rg_cost_plus_bracket_number    
,rg_merchandiser                
,rg_pricing_flag                
,rg_salesman                    
,rg_skid_rounding_flag          
,dsd_vendor                     
,cust_code_xref                 
,site_pick_slip_req             
,site_pick_slip_req_disp        
,site_rank                      
,acc_subs                       
,rej_reason                     
,max_vol_pall                   
,item_pal_round                 
,log_ord_qty                    
,min_ord_qty                    
,enforce_dept                   
,max_ord_qty                    
,po_req                         
,po_req_disp                    
,ret_prc_req                    
,ret_prc_req_disp               
,cust_xref                      
,cust_xref_disp                 
,legacy_cust_nbr                
,legacy_company                 
,bill_to_site_use_id            
,ship_to_site_use_id            
,hosting_dept                   
,retailer_dept                  
,contact_info                   
,store_manager                  
,store_owner                    
,store_type                     
,accept_subs                    
,int_po_req                     
,division_id                    
,region                         
,delegate_autriztn_flg          
,aisle_limit                    
,acct_type                      
,old_store_nbr                  
,gs_dash_0                      
,gs_dash_0_description          
,gs_dash_1                      
,gs_dash_1_description          
,gs_dash_2                      
,gs_dash_2_description          
,gs_dash_3                      
,gs_dash_3_description          
,gs_dash_4                      
,gs_dash_4_description          
,gs_dash_5                      
,gs_dash_5_description          
,gs_dash_6                      
,gs_dash_6_description          
,gs_dash_7                      
,gs_dash_7_description          
,gs_dash_8                      
,gs_dash_8_description          
,gs_dash_9                      
,gs_dash_9_description          
,platinum_dept                  
,exclude_pdf_bkp                
,gs_adv_crd_groc_rpk_cayu_pct   
,gs_adv_crd_meat_bulk_pct       
,gs_adv_crd_corder_repack_pct   
,gs_adv_crd_frozen_pct          
,gs_adv_crd_bakery_pct          
,gs_adv_crd_refrig_pct          
,gs_adv_crd_icream_pct          
,gs_salesman_nbr                
,gs_salesman_name               
,gs_cm_drop_ship_flag           
,gs_cm_payment_method           
,gs_selection_service_fee_flag  
,gs_frz_rbt_flag                
,gs_stmt_froz_adj_factor        
,gs_stmt_meat_adj_factor        
,gs_stmt_groc_adj_factor        
,gs_note_payoff_credit_rate     
,gs_sales_adj_rebate_rate       
,gs_transfer_bal_dash_nbr       
,gs_cust_cross_ref_dash_nbr     
,gs_rebate_check                
,gs_group_code_desc             
,gs_portal_folder_nbr           
,store_fax_nbr                  
,gs_aud_group                   
,credit_limit                   
,gs_map_cd                      
,gs_map_cd_ltr                  
,gs_vendor_pack_ind             
,gs_ad_group                    
,gs_tpr_group                   
,gs_gby_group                   
,gs_pricing_zone                
,gs_super_serve                 
,gs_nabisco                     
,gs_will_call                   
,swell                          
,hq_flag                        
,gs_primary_ship_flag           
,gs_fuel_zone                   
,gs_fuel_zone_desc              
,gs_ad_group_desc               
,gs_pricing_zone_desc'''    
# Remove the triple quotes, and then split the string using comma as the delimiter
# Remove the triple quotes and any white spaces or newline characters, then split the string using comma as the delimiter
result_list = update_columns.replace('\n', '').replace(' ','').strip("'''").split(',')
print(len(result_list))

print(len(result_list))
print(sorted(result_list))
# Out:
# 319
# 319
# ['acc_subs', 'accept_subs', 'acct_creation_date', 'acct_cust_class_code', 'acct_id', 'acct_name', 'acct_nbr', 'acct_status', 'acct_type', 'ad_comments', 'ad_plan_group', 'ad_start_day_of_week', 'adv_flag5', 'adv_flag6', 'adv_flag8', 'adv_flag_7', 'agne_customer', 'aisle_limit', 'alt_cust_nbr', 'ar_group_name', 'ar_segment_group', 'awi_ad_offset', 'awi_cdh_customer_class', 'awi_cdh_rack_service', 'awi_customer_type', 'awi_multi_store_nbr', 'awi_party_site_id', 'awi_print_bulletin', 'awi_product', 'awi_sign_kit', 'base_cust_nbr', 'bb_ad_plan', 'bb_mod_program', 'bill_to_site_use_id', 'bill_to_store_name', 'bill_to_store_nbr', 'blank_check_customer', 'c_cost_plus_bracket_flag', 'c_cost_plus_bracket_number', 'c_merchandiser', 'c_pricing_flag', 'c_salesman', 'c_skid_rounding_flag', 'call_for_customer', 'catalog10', 'chain_inactive_date', 'chain_name', 'chain_nbr', 'chain_short_name', 'cigarette_license', 'cigarette_validation', 'cm_billing_cycle', 'cm_cust_xref_no', 'cm_group_code', 'cm_np_xfer_flag', 'cm_payment_due_days', 'cm_payment_method', 'cm_print_stmt', 'cm_ret_acct_stmt', 'cm_stmt_copies', 'cm_stmt_labels', 'cm_sub_store', 'cm_terms', 'cod', 'collector_name', 'company_code', 'confo', 'confo_ad_plan', 'contact_info', 'credit_group', 'credit_hold', 'credit_limit', 'cust_acct_profile_id', 'cust_code_xref', 'cust_statement_format', 'cust_store_nbr', 'cust_xref', 'cust_xref_disp', 'customer_group', 'd_cost_plus_bracket_flag', 'd_cost_plus_bracket_number', 'd_merchandiser', 'd_pricing_flag', 'd_salesman', 'd_skid_rounding_flag', 'default_trip', 'delegate_autriztn_flg', 'delinquent_start_date', 'division_id', 'division_name', 'division_nbr', 'dsd_vendor', 'ebs_gl_cust_group_name', 'ebs_gl_cust_group_nbr', 'eft', 'eight_week_bb', 'end_cust_nbr', 'end_cust_nbr2', 'enforce_dept', 'exclude_pdf_bkp', 'f_cost_plus_bracket_flag', 'f_cost_plus_bracket_number', 'f_merchandiser', 'f_pricing_flag', 'f_salesman', 'f_skid_rounding_flag', 'finance_charge_effective_date', 'finance_charges', 'gas_rewards', 'gm_cost_plus_bracket_flag', 'gm_cost_plus_bracket_number', 'gm_merchandiser', 'gm_pricing_flag', 'gm_salesman', 'gm_skid_rounding_flag', 'group_buy_nbr', 'gs_ad_group', 'gs_ad_group_desc', 'gs_adv_crd_bakery_pct', 'gs_adv_crd_corder_repack_pct', 'gs_adv_crd_frozen_pct', 'gs_adv_crd_groc_rpk_cayu_pct', 'gs_adv_crd_icream_pct', 'gs_adv_crd_meat_bulk_pct', 'gs_adv_crd_refrig_pct', 'gs_aud_group', 'gs_cm_drop_ship_flag', 'gs_cm_payment_method', 'gs_cust_cross_ref_dash_nbr', 'gs_dash_0', 'gs_dash_0_description', 'gs_dash_1', 'gs_dash_1_description', 'gs_dash_2', 'gs_dash_2_description', 'gs_dash_3', 'gs_dash_3_description', 'gs_dash_4', 'gs_dash_4_description', 'gs_dash_5', 'gs_dash_5_description', 'gs_dash_6', 'gs_dash_6_description', 'gs_dash_7', 'gs_dash_7_description', 'gs_dash_8', 'gs_dash_8_description', 'gs_dash_9', 'gs_dash_9_description', 'gs_frz_rbt_flag', 'gs_fuel_zone', 'gs_fuel_zone_desc', 'gs_gby_group', 'gs_group_code_desc', 'gs_map_cd', 'gs_map_cd_ltr', 'gs_nabisco', 'gs_note_payoff_credit_rate', 'gs_portal_folder_nbr', 'gs_pricing_zone', 'gs_pricing_zone_desc', 'gs_primary_ship_flag', 'gs_rebate_check', 'gs_retail_acctng_report', 'gs_sales_adj_rebate_rate', 'gs_salesman_name', 'gs_salesman_nbr', 'gs_selection_service_fee_flag', 'gs_stmt_froz_adj_factor', 'gs_stmt_groc_adj_factor', 'gs_stmt_meat_adj_factor', 'gs_super_serve', 'gs_tpr_group', 'gs_transfer_bal_dash_nbr', 'gs_vendor_pack_ind', 'gs_will_call', 'hba_gm_disc', 'hba_gm_disc_overide', 'hba_gm_flag', 'hosting_dept', 'hq_cust_nbr', 'hq_flag', 'imported_source', 'int_po_req', 'interest_period_days', 'interest_rate', 'invoice_tolrnce', 'item_allowance', 'item_pal_round', 'kpc_end', 'kpc_retail_zone', 'kpc_start', 'last_update_date', 'last_update_login', 'last_updated_by', 'legacy_company', 'legacy_cust_nbr', 'location_id', 'log_ord_qty', 'm_cost_plus_bracket_flag', 'm_cost_plus_bracket_number', 'm_merchandiser', 'm_pricing_flag', 'm_salesman', 'm_skid_rounding_flag', 'max_ord_ ...

# %%
cust_gtt = ['PARTY_SITE_ID', 'STORE_NBR', 'STORE_NAME', 'STORE_STATUS', 'STORE_BILL_TO_FLAG', 'STORE_SHIP_TO_FLAG', 'ACCT_ID', 'ACCT_NBR', 'ACCT_NAME', 'ACCT_STATUS', 'ACCT_CUST_CLASS_CODE', 'ACCT_CREATION_DATE', 'CHAIN_NBR', 'CHAIN_NAME', 'CHAIN_SHORT_NAME', 'CHAIN_INACTIVE_DATE', 'START_CUST_NBR', 'STRT_CUST_NBR2', 'END_CUST_NBR', 'END_CUST_NBR2', 'PRIVATE_LABEL_OFFSET', 'SUB_AUTH_OFFST', 'AD_START_DAY_OF_WEEK', 'COMPANY_CODE', 'HQ_CUST_NBR', 'DIVISION_NBR', 'DIVISION_NAME', 'EBS_GL_CUST_GROUP_NBR', 'EBS_GL_CUST_GROUP_NAME', 'STORE_GROUP_NBR', 'STORE_GROUP_NAME', 'GROUP_BUY_NBR', 'STORE_CREATION_DATE', 'STORE_INACTIVE_DATE', 'STORE_LAST_UPDATE_DATE', 'LOCATION_ID', 'STORE_ADDRESS1', 'STORE_ADDRESS2', 'STORE_ADDRESS3', 'STORE_ADDRESS4', 'STORE_CITY', 'STORE_POSTAL_CODE', 'STORE_STATE', 'STORE_PROVINCE', 'STORE_COUNTY', 'STORE_COUNTRY', 'STORE_TELEPHONE_NBR', 'CUST_STORE_NBR', 'CUST_ACCT_PROFILE_ID', 'PAY_TERMS', 'PAY_TERM_DESC', 'PAY_TERM_START_DATE', 'PAY_TERM_END_DATE', 'COLLECTOR_NAME', 'STATEMENT_CYCLE_NAME', 'ALT_CUST_NBR', 'BASE_CUST_NBR', 'CUST_STATEMENT_FORMAT', 'PACA_FLAG', 'TOBACCO_BILLABLE_FLAG', 'TOBACCO_REBATE', 'ZONE_NBR', 'MILITARY_DODAAC', 'SALES_REPRESENTATIVE', 'BILL_TO_STORE_NBR', 'BILL_TO_STORE_NAME', 'PRIMARY_CONTACT_NAME', 'PRIMARY_CONTACT_PHONE_NBR', 'PRIMARY_CONTACT_EMAIL_ADDR', 'CUSTOMER_GROUP', 'STORE_GROUP', 'FINANCE_CHARGES', 'INTEREST_RATE', 'PAYMENT_GRACE_DAYS', 'INTEREST_PERIOD_DAYS', 'STATEMENT_ADDRESS1', 'STATEMENT_CITY', 'STATEMENT_STATE', 'STATEMENT_ZIP', 'FINANCE_CHARGE_EFFECTIVE_DATE', 'SUMMARY_STMT_FORMAT', 'DELINQUENT_START_DATE', 'AR_SEGMENT_GROUP', 'AR_GROUP_NAME', 'IMPORTED_SOURCE', 'REMITTANCE_ADDR', 'STATEMENT_TOLRNCE', 'INVOICE_TOLRNCE', 'SALES_REP', 'RISK_TIER', 'GS_RETAIL_ACCTNG_REPORT', 'STATEMENT_LEVEL', 'RELATED_CUST_LOCKBOX_APPLLY', 'SEND_ACH_NOTIFTN', 'STOCK_NAME', 'MULTI_STORE', 'EFT', 'PICKUP_DAY', 'PAY_DUE_DAY', 'CREDIT_HOLD', 'PAYMENT_TERMS', 'CREDIT_GROUP', 'BLANK_CHECK_CUSTOMER', 'AD_PLAN_GROUP', 'AWI_PARTY_SITE_ID', 'AWI_MULTI_STORE_NBR', 'PATRONAGE_NBR', 'PRINT_STATEMENTS', 'STATEMENT_INSTRUCTIONS', 'SEND_TO_AWI_CDH_FLG', 'CM_BILLING_CYCLE', 'CM_TERMS', 'CM_NP_XFER_FLAG', 'CM_PRINT_STMT', 'CM_RET_ACCT_STMT', 'CM_STMT_COPIES', 'CM_GROUP_CODE', 'CM_PAYMENT_METHOD', 'CM_STMT_LABELS', 'CM_PAYMENT_DUE_DAYS', 'CM_SUB_STORE', 'CM_CUST_XREF_NO', 'STMT_ADJ_GROUP_CODE', 'PSUEDOEPHEDRINE_FLAG', 'CALL_FOR_CUSTOMER', 'CIGARETTE_LICENSE', 'SMALL_PACK', 'CIGARETTE_VALIDATION', 'AWI_CDH_CUSTOMER_CLASS', 'GAS_REWARDS', 'MILES', 'PRINT_STMTS', 'AWI_CDH_RACK_SERVICE', 'RETAIL_TYPE', 'TAX_EXEMPT', 'ADV_FLAG_7', 'ADV_FLAG6', 'BB_AD_PLAN', 'AD_COMMENTS', 'ADV_FLAG5', 'CONFO_AD_PLAN', 'DEFAULT_TRIP', 'CATALOG10', 'AWI_PRINT_BULLETIN', 'AWI_SIGN_KIT', 'SURVEYS', 'ADV_FLAG8', 'AWI_AD_OFFSET', 'AGNE_CUSTOMER', 'CONFO', 'HBA_GM_FLAG', 'HBA_GM_DISC_OVERIDE', 'HBA_GM_DISC', 'ITEM_ALLOWANCE', 'COD', 'SERV_CHARGE', 'SINGLE_PICK', 'AWI_CUSTOMER_TYPE', 'MULTI_STORE_NUMBER', 'EIGHT_WEEK_BB', 'BB_MOD_PROGRAM', 'KPC_END', 'KPC_RETAIL_ZONE', 'KPC_START', 'AWI_PRODUCT', 'SPECIALTY_FOODS', 'D_COST_PLUS_BRACKET_FLAG', 'D_COST_PLUS_BRACKET_NUMBER', 'D_MERCHANDISER', 'D_PRICING_FLAG', 'D_SALESMAN', 'D_SKID_ROUNDING_FLAG', 'SY_COST_PLUS_BRACKET_FLAG', 'SY_COST_PLUS_BRACKET_NUMBER', 'SY_MERCHANDISER', 'SY_PRICING_FLAG', 'SY_SALESMAN', 'SY_SKID_ROUNDING_FLAG', 'M_COST_PLUS_BRACKET_FLAG', 'M_COST_PLUS_BRACKET_NUMBER', 'M_MERCHANDISER', 'M_PRICING_FLAG', 'M_SALESMAN', 'M_SKID_ROUNDING_FLAG', 'P_COST_PLUS_BRACKET_FLAG', 'P_COST_PLUS_BRACKET_NUMBER', 'P_MERCHANDISER', 'P_PRICING_FLAG', 'P_SALESMAN', 'P_SKID_ROUNDING_FLAG', 'GM_COST_PLUS_BRACKET_FLAG', 'GM_COST_PLUS_BRACKET_NUMBER', 'GM_MERCHANDISER', 'GM_PRICING_FLAG', 'GM_SALESMAN', 'GM_SKID_ROUNDING_FLAG', 'C_COST_PLUS_BRACKET_FLAG', 'C_COST_PLUS_BRACKET_NUMBER', 'C_MERCHANDISER', 'C_PRICING_FLAG', 'C_SALESMAN', 'C_SKID_ROUNDING_FLAG', 'F_COST_PLUS_BRACKET_FLAG', 'F_COST_PLUS_BRACKET_NUMBER', 'F_MERCHANDISER', 'F_PRICING_FLAG', 'F_SALESMAN', 'F_SKID_ROUNDING_FLAG', 'RG_COST_PLUS_BRACKET_FLAG', 'RG_COST_PLUS_BRACKET_NUMBER', 'RG_MERCHANDISER', 'RG_PRICING_FLAG', 'RG_SALESMAN', 'RG_SKID_ROUNDING_FLAG', 'DSD_VENDOR', 'CUST_CODE_XREF', 'SITE_PICK_SLIP_REQ', 'SITE_PICK_SLIP_REQ_DISP', 'SITE_RANK', 'ACC_SUBS', 'REJ_REASON', 'MAX_VOL_PALL', 'ITEM_PAL_ROUND', 'LOG_ORD_QTY', 'MIN_ORD_QTY', 'ENFORCE_DEPT', 'MAX_ORD_QTY', 'PO_REQ', 'PO_REQ_DISP', 'RET_PRC_REQ', 'RET_PRC_REQ_DISP', 'CUST_XREF', 'CUST_XREF_DISP', 'LEGACY_CUST_NBR', 'LEGACY_COMPANY', 'BILL_TO_SITE_USE_ID', 'SHIP_TO_SITE_USE_ID', 'HOSTING_DEPT', 'RETAILER_DEPT', 'CONTACT_INFO', 'STORE_MANAGER', 'STORE_OWNER', 'STORE_TYPE', 'ACCEPT_SUBS', 'INT_PO_REQ', 'DIVISION_ID', 'REGION', 'DELEGATE_AUTRIZTN_FLG', 'AISLE_LIMIT', 'ACCT_TYPE', 'OLD_STORE_NBR', 'GS_DASH_0', 'GS_DASH_0_DESCRIPTION', 'GS_DASH_1', 'GS_DASH_1_DESCRIPTION', 'GS_DASH_2', 'GS_DASH_2_DESCRIPTION', 'GS_DASH_3', 'GS_DASH_3_DESCRIPTION', 'GS_DASH_4', 'GS_DASH_4_DESCRIPTION', 'GS_DASH_5', 'GS_DASH_5_DESCRIPTION', 'GS_DASH_6', 'GS_DASH_6_DESCRIPTION', 'GS_DASH_7', 'GS_DASH_7_DESCRIPTION', 'GS_DASH_8', 'GS_DASH_8_DESCRIPTION', 'GS_DASH_9', 'GS_DASH_9_DESCRIPTION', 'PLATINUM_DEPT', 'EXCLUDE_PDF_BKP', 'GS_ADV_CRD_GROC_RPK_CAYU_PCT', 'GS_ADV_CRD_MEAT_BULK_PCT', 'GS_ADV_CRD_CORDER_REPACK_PCT', 'GS_ADV_CRD_FROZEN_PCT', 'GS_ADV_CRD_BAKERY_PCT', 'GS_ADV_CRD_REFRIG_PCT', 'GS_ADV_CRD_ICREAM_PCT', 'GS_SALESMAN_NBR', 'GS_SALESMAN_NAME', 'GS_CM_DROP_SHIP_FLAG', 'GS_CM_PAYMENT_METHOD', 'GS_SELECTION_SERVICE_FEE_FLAG', 'GS_FRZ_RBT_FLAG', 'GS_STMT_FROZ_ADJ_FACTOR', 'GS_STMT_MEAT_ADJ_FACTOR', 'GS_STMT_GROC_ADJ_FACTOR', 'GS_NOTE_PAYOFF_CREDIT_RATE', 'GS_SALES_ADJ_REBATE_RATE', 'GS_TRANSFER_BAL_DASH_NBR', 'GS_CUST_CROSS_REF_DASH_NBR', 'GS_REBATE_CHECK', 'GS_GROUP_CODE_DESC', 'GS_PORTAL_FOLDER_NBR', 'STORE_FAX_NBR', 'GS_AUD_GROUP', 'CREDIT_LIMIT', 'GS_MAP_CD', 'GS_MAP_CD_LTR', 'GS_VENDOR_PACK_IND', 'GS_AD_GROUP', 'GS_TPR_GROUP', 'GS_GBY_GROUP', 'GS_PRICING_ZONE', 'GS_SUPER_SERVE', 'GS_NABISCO', 'GS_WILL_CALL', 'SWELL', 'HQ_FLAG', 'GS_PRIMARY_SHIP_FLAG', 'GS_FUEL_ZONE', 'GS_FUEL_ZONE_DESC', 'GS_AD_GROUP_DESC', 'GS_PRICING_ZONE_DESC']
len(cust_gtt)
sorted(cust_gtt)
# Out:
# ['ACCEPT_SUBS',
#  'ACCT_CREATION_DATE',
#  'ACCT_CUST_CLASS_CODE',
#  'ACCT_ID',
#  'ACCT_NAME',
#  'ACCT_NBR',
#  'ACCT_STATUS',
#  'ACCT_TYPE',
#  'ACC_SUBS',
#  'ADV_FLAG5',
#  'ADV_FLAG6',
#  'ADV_FLAG8',
#  'ADV_FLAG_7',
#  'AD_COMMENTS',
#  'AD_PLAN_GROUP',
#  'AD_START_DAY_OF_WEEK',
#  'AGNE_CUSTOMER',
#  'AISLE_LIMIT',
#  'ALT_CUST_NBR',
#  'AR_GROUP_NAME',
#  'AR_SEGMENT_GROUP',
#  'AWI_AD_OFFSET',
#  'AWI_CDH_CUSTOMER_CLASS',
#  'AWI_CDH_RACK_SERVICE',
#  'AWI_CUSTOMER_TYPE',
#  'AWI_MULTI_STORE_NBR',
#  'AWI_PARTY_SITE_ID',
#  'AWI_PRINT_BULLETIN',
#  'AWI_PRODUCT',
#  'AWI_SIGN_KIT',
#  'BASE_CUST_NBR',
#  'BB_AD_PLAN',
#  'BB_MOD_PROGRAM',
#  'BILL_TO_SITE_USE_ID',
#  'BILL_TO_STORE_NAME',
#  'BILL_TO_STORE_NBR',
#  'BLANK_CHECK_CUSTOMER',
#  'CALL_FOR_CUSTOMER',
#  'CATALOG10',
#  'CHAIN_INACTIVE_DATE',
#  'CHAIN_NAME',
#  'CHAIN_NBR',
#  'CHAIN_SHORT_NAME',
#  'CIGARETTE_LICENSE',
#  'CIGARETTE_VALIDATION',
#  'CM_BILLING_CYCLE',
#  'CM_CUST_XREF_NO',
#  'CM_GROUP_CODE',
#  'CM_NP_XFER_FLAG',
#  'CM_PAYMENT_DUE_DAYS',
#  'CM_PAYMENT_METHOD',
#  'CM_PRINT_STMT',
#  'CM_RET_ACCT_STMT',
#  'CM_STMT_COPIES',
#  'CM_STMT_LABELS',
#  'CM_SUB_STORE',
#  'CM_TERMS',
#  'COD',
#  'COLLECTOR_NAME',
#  'COMPANY_CODE',
#  'CONFO',
#  'CONFO_AD_PLAN',
#  'CONTACT_INFO',
#  'CREDIT_GROUP',
#  'CREDIT_HOLD',
#  'CREDIT_LIMIT',
#  'CUSTOMER_GROUP',
#  'CUST_ACCT_PROFILE_ID',
#  'CUST_CODE_XREF',
#  'CUST_STATEMENT_FORMAT',
#  'CUST_STORE_NBR',
#  'CUST_XREF',
#  'CUST_XREF_DISP',
#  'C_COST_PLUS_BRACKET_FLAG',
#  'C_COST_PLUS_BRACKET_NUMBER',
#  'C_MERCHANDISER',
#  'C_PRICING_FLAG',
#  'C_SALESMAN',
#  'C_SKID_ROUNDING_FLAG',
#  'DEFAULT_TRIP',
#  'DELEGATE_AUTRIZTN_FLG',
#  'DELINQUENT_START_DATE',
#  'DIVISION_ID',
#  'DIVISION_NAME',
#  'DIVISION_NBR',
#  'DSD_VENDOR',
#  'D_COST_PLUS_BRACKET_FLAG',
#  'D_COST_PLUS_BRACKET_NUMBER',
#  'D_MERCHANDISER',
#  'D_PRICING_FLAG',
#  'D_SALESMAN',
#  'D_SKID_ROUNDING_FLAG',
#  'EBS_GL_CUST_GROUP_NAME',
#  'EBS_GL_CUST_GROUP_NBR',
#  'EFT',
#  'EIGHT_WEEK_BB',
#  'END_CUST_NBR',
#  'END_CUST_NBR2',
#  'ENFORCE_DEPT',
#  'EXCLUDE_PDF_BKP',
#  'FINANCE_CHARGES',
#  'FINANCE_CHARGE_EFFECTIVE_DATE',
#  'F_COST_PLUS_BRACKET_FLAG',
#  'F_COST_PLUS_BRACKET_NUMBER',
#  'F_MERCHANDISER',
#  'F_PRICING_FLAG',
#  'F_SALESMAN',
#  'F_SKID_ROUNDING_FLAG',
#  'GAS_REWARDS',
#  'GM_COST_PLUS_BRACKET_FLAG',
#  'GM_COST_PLUS_BRACKET_NUMBER',
#  'GM_MERCHANDISER',
#  'GM_PRICING_FLAG',
#  'GM_SALESMAN',
#  'GM_SKID_ROUNDING_FLAG',
#  'GROUP_BUY_NBR',
#  'GS_ADV_CRD_BAKERY_PCT',
#  'GS_ADV_CRD_CORDER_REPACK_PCT',
#  'GS_ADV_CRD_FROZEN_PCT',
#  'GS_ADV_CRD_GROC_RPK_CAYU_PCT',
#  'GS_ADV_CRD_ICREAM_PCT',
#  'GS_ADV_CRD_MEAT_BULK_PCT',
#  'GS_ADV_CRD_REFRIG_PCT',
#  'GS_AD_GROUP',
#  'GS_AD_GROUP_DESC',
#  'GS_AUD_GROUP',
#  'GS_CM_DROP_SHIP_FLAG',
#  'GS_CM_PAYMENT_METHOD',
#  'GS_CUST_CROSS_REF_DASH_NBR',
#  'GS_DASH_0',
#  'GS_DASH_0_DESCRIPTION',
#  'GS_DASH_1',
#  'GS_DASH_1_DESCRIPTION',
#  'GS_DASH_2',
#  'GS_DASH_2_DESCRIPTION',
#  'GS_DASH_3',
#  'GS_DASH_3_DESCRIPTION',
#  'GS_DASH_4',
#  'GS_DASH_4_DESCRIPTION',
#  'GS_DASH_5',
#  'GS_DASH_5_DESCRIPTION',
#  'GS_DASH_6',
#  'GS_DASH_6_DESCRIPTION',
#  'GS_DASH_7',
#  'GS_DASH_7_DESCRIPTION',
#  'GS_DASH_8',
#  'GS_DASH_8_DESCRIPTION',
#  'GS_DASH_9',
#  'GS_DASH_9_DESCRIPTION',
#  'GS_FRZ_RBT_FLAG',
#  'GS_FUEL_ZONE',
#  'GS_FUEL_ZONE_DESC',
#  'GS_GBY_GROUP',
#  'GS_GROUP_CODE_DESC',
#  'GS_MAP_CD',
#  'GS_MAP_CD_LTR',
#  'GS_NABISCO',
#  'GS_NOTE_PAYOFF_CREDIT_RATE',
#  'GS_PORTAL_FOLDER_NBR',
#  'GS_PRICING_ZONE',
#  'GS_PRICING_ZONE_DESC',
#  'GS_PRIMARY_SHIP_FLAG',
#  'GS_REBATE_CHECK',
#  'GS_RETAIL_ACCTNG_REPORT',
#  'GS_SALESMAN_NAME',
#  'GS_SALESMAN_NBR',
#  'GS_SALES_ADJ_REBATE_RATE',
#  'GS_SELECTION_SERVICE_FEE_FLAG',
#  'GS_STMT_FROZ_ADJ_FACTOR',
#  'GS_STMT_GROC_ADJ_FACTOR',
#  'GS_STMT_MEAT_ADJ_FACTOR',
#  'GS_SUPER_SERVE',
#  'GS_TPR_GROUP',
#  'GS_TRANSFER_BAL_DASH_NBR',
#  'GS_VENDOR_PACK_IND',
#  'GS_WILL_CALL',
#  'HBA_GM_DISC',
#  'HBA_GM_DISC_OVERIDE',
#  'HBA_GM_FLAG',
#  'HOSTING_DEPT',
#  'HQ_CUST_NBR',
#  'HQ_FLAG',
#  'IMPORTED_SOURCE',
#  'INTEREST_PERIOD_DAYS',
#  'INTEREST_RATE',
#  'INT_PO_REQ',
#  'INVOICE_TOLRNCE',
#  'ITEM_ALLOWANCE',
#  'ITEM_PAL_ROUND',
#  'KPC_END',
#  'KPC_RETAIL_ZONE',
#  'KPC_START',
#  'LEGACY_COMPANY',
#  'LEGACY_CUST_NBR',
#  'LOCATION_ID',
#  'LOG_ORD_QTY',
#  'MAX_ORD_QTY',
#  'MAX_VOL_PALL',
#  'MILES',
#  'MILITARY_DODAAC',
#  'MIN_ORD_QTY',
#  'MULTI_STORE',
#  'MULTI_STORE_NUMBER',
#  'M_COST_PLUS_BRACKET_FLAG',
#  'M_COST_PLUS_BRACKET_NUMBER',
#  'M_MERCHANDISER',
#  'M_PRICING_FLAG',
#  'M_SALESMAN',
#  'M_SKID_ROUNDING_FLAG',
#  'OLD_STORE_NBR',
#  'PACA_FLAG',
#  'PARTY_SITE_ID',
#  'PATRONAGE_NBR',
#  'PAYMENT_GRACE_DAYS',
#  'PAYMENT_TERMS',
#  'PAY_DUE_DAY',
#  'PAY_TERMS',
#  'PAY_TERM_DESC',
#  'PAY_TERM_END_DATE',
#  'PAY_TERM_START_DATE',
#  'PICKUP_DAY',
#  'PLATINUM_DEPT',
#  'PO_REQ',
#  'PO_REQ_DISP',
#  'PRIMARY_CONTACT_EMAIL_ADDR',
#  'PRIMARY_CONTACT_NAME',
#  'PRIMARY_CONTACT_PHONE_NBR',
#  'PRINT_STATEMENTS',
#  'PRINT_STMTS',
#  'PRIVATE_LABEL_OFFSET',
#  'PSUEDOEPHEDRINE_FLAG',
#  'P_COST_PLUS_BRACKET_FLAG',
#  'P_COST_PLUS_BRACKET_NUMBER',
#  'P_MERCHANDISER',
#  'P_PRICING_FLAG',
#  'P_SALESMAN',
#  'P_SKID_ROUNDING_FLAG',
#  'REGION',
#  'REJ_REASON',
#  'RELATED_CUST_LOCKBOX_APPLLY',
#  'REMITTANCE_ADDR',
#  'RETAILER_DEPT',
#  'RETAIL_TYPE',
#  'RET_PRC_REQ',
#  'RET_PRC_REQ_DISP',
#  'RG_COST_PLUS_BRACKET_FLAG',
#  'RG_COST_PLUS_BRACKET_NUMBER',
#  'RG_MERCHANDISER',
#  'RG_PRICING_FLAG',
#  'RG_SALESMAN',
#  'RG_SKID_ROUNDING_FLAG',
#  'RISK_TIER',
#  'SALES_REP',
#  'SALES_REPRESENTATIVE',
#  'SEND_ACH_NOTIFTN',
#  'SEND_TO_AWI_CDH_FLG',
#  'SERV_CHARGE',
#  'SHIP_TO_SITE_USE_ID',
#  'SINGLE_PICK',
#  'SITE_PICK_SLIP_REQ',
#  'SITE_PICK_SLIP_REQ_DISP',
#  'SITE_RANK',
#  'SMALL_PACK',
#  'SPECIALTY_FOODS',
#  'START_CUST_NBR',
#  'STATEMENT_ADDRESS1',
#  'STATEMENT_CITY',
#  'STATEMENT_CYCLE_NAME',
#  'STATEMENT_INSTRUCTIONS',
#  'STATEMENT_LEVEL',
#  'STATEMENT_STATE',
#  'STATEMENT_TOLRNCE',
#  'STATEMENT_ZIP',
#  'STMT_ADJ_GROUP_CODE',
#  'STOCK_NAME',
#  'STORE_ADDRESS1',
#  'STORE_ADDRESS2',
#  'STORE_ADDRESS3',
#  'STORE_ADDRESS4',
#  'STORE_BILL_TO_FLAG',
#  'STORE_CITY',
#  'STORE_COUNTRY',
#  'STORE_COUNTY',
#  'STORE_CREATION_DATE',
#  'STORE_FAX_NBR',
#  'STORE_GROUP',
#  'STORE_GROUP_NAME',
#  'STORE_GROUP_NBR',
#  'STORE_INACTIVE_DATE',
#  'STORE_LAST_UPDATE_DATE',
#  'STORE_MANAGER',
#  'STORE_NAME',
#  'STORE_NBR',
#  'STORE_OWNER',
#  'STORE_POSTAL_CODE',
#  'STORE_PROVINCE',
#  'STORE_SHIP_TO_FLAG',
#  'STORE_STATE',
#  'STORE_STATUS',
#  'STORE_TELEPHONE_NBR',
#  'STORE_TYPE',
#  'STRT_CUST_NBR2',
#  'SUB_AUTH_OFFST',
#  'SUMMARY_STMT_FORMAT',
#  'SURVEYS',
#  'SWELL',
#  'SY_COST_PLUS_BRACKET_FLAG',
#  'SY_COST_PLUS_BRACKET_NUMBER',
#  'SY_MERCHANDISER',
#  'SY_PRICING_FLAG',
#  'SY_SALESMAN',
#  'SY_SKID_ROUNDING_FLAG',
#  'TAX_EXEMPT',
#  'TOBACCO_BILLABLE_FLAG',
#  'TOBACCO_REBATE',
#  'ZONE_NBR']

# %%
# Convert lists to sets and find the difference
elements_not_in_cust_gtt = set(result_list) - set(cust_gtt)

# Convert the result back to a list
result = list(elements_not_in_cust_gtt)

print(result)
# Out:
# ['gs_dash_4_description', 'store_state', 'hba_gm_disc', 'gs_selection_service_fee_flag', 'gs_map_cd_ltr', 'cust_statement_format', 'site_rank', 'p_pricing_flag', 'surveys', 'bill_to_store_nbr', 'zone_nbr', 'legacy_cust_nbr', 'awi_multi_store_nbr', 'f_cost_plus_bracket_flag', 'ar_segment_group', 'psuedoephedrine_flag', 'stock_name', 'cust_store_nbr', 'gs_dash_1', 'contact_info', 'hq_flag', 'store_group', 'pay_term_desc', 'tobacco_billable_flag', 'exclude_pdf_bkp', 'region', 'gs_dash_9', 'statement_cycle_name', 'summary_stmt_format', 'gs_dash_7_description', 'pay_terms', 'gs_dash_4', 'specialty_foods', 'gs_adv_crd_groc_rpk_cayu_pct', 'miles', 'acct_creation_date', 'confo_ad_plan', 'blank_check_customer', 'sub_auth_offst', 'store_creation_date', 'last_update_date', 'store_last_update_date', 'log_ord_qty', 'adv_flag6', 'rg_cost_plus_bracket_flag', 'adv_flag8', 'm_merchandiser', 'store_country', 'agne_customer', 'adv_flag_7', 'ad_comments', 'f_cost_plus_bracket_number', 'item_allowance', 'gs_adv_crd_icream_pct', 'kpc_end', 'related_cust_lockbox_applly', 'gs_will_call', 'gs_cm_payment_method', 'sy_merchandiser', 'hosting_dept', 'end_cust_nbr2', 'retailer_dept', 'gs_transfer_bal_dash_nbr', 'end_cust_nbr', 'c_merchandiser', 'ret_prc_req_disp', 'store_address2', 'sy_pricing_flag', 'legacy_company', 'company_code', 'm_pricing_flag', 'gs_dash_3', 'enforce_dept', 'gs_dash_2', 'c_cost_plus_bracket_flag', 'awi_party_site_id', 'sy_cost_plus_bracket_number', 'gm_cost_plus_bracket_number', 'old_store_nbr', 'acct_id', 'stmt_adj_group_code', 'awi_cdh_rack_service', 'collector_name', 'store_manager', 'group_buy_nbr', 'cm_stmt_labels', 'aisle_limit', 'gs_dash_1_description', 'gs_ad_group', 'acct_name', 'cm_cust_xref_no', 'rg_merchandiser', 'awi_ad_offset', 'request_id', 'gs_adv_crd_frozen_pct', 'cm_np_xfer_flag', 'credit_limit', 'p_cost_plus_bracket_flag', 'max_vol_pall', 'c_salesman', 'd_cost_plus_bracket_number', 'kpc_start', 'cm_print_stmt', 'tobacco_rebate', 'gs_salesman_nbr', 'acct_status', 'gs_dash_0', 'imported_source', 'print_stmts', 'primary_contact_name', 'gas_rewards', 'payment_terms', 'gm_skid_rounding_flag', 'store_type', 'store_fax_nbr', 'awi_sign_kit', 'gs_pricing_zone', 'pay_due_day', 'adv_flag5', 'ad_start_day_of_week', 'single_pick', 'cust_acct_profile_id', 'private_label_offset', 'statement_instructions', 'division_name', 'dsd_vendor', 'gs_dash_3_description', 'store_inactive_date', 'gs_dash_7', 'platinum_dept', 'p_skid_rounding_flag', 'gs_adv_crd_bakery_pct', 'c_pricing_flag', 'rg_cost_plus_bracket_number', 'rg_pricing_flag', 'item_pal_round', 'retail_type', 'pay_term_start_date', 'sy_salesman', 'interest_rate', 'int_po_req', 'customer_group', 'store_telephone_nbr', 'send_ach_notiftn', 'cust_xref', 'gs_note_payoff_credit_rate', 'hba_gm_flag', 'm_salesman', 'm_cost_plus_bracket_number', 'acc_subs', 'multi_store', 'cigarette_license', 'interest_period_days', 'acct_nbr', 'gs_sales_adj_rebate_rate', 'risk_tier', 'bill_to_site_use_id', 'gs_pricing_zone_desc', 'patronage_nbr', 'store_address3', 'primary_contact_email_addr', 'eight_week_bb', 'chain_short_name', 'statement_zip', 'hq_cust_nbr', 'p_cost_plus_bracket_number', 'cm_payment_method', 'delegate_autriztn_flg', 'store_group_nbr', 'store_nbr', 'last_update_login', 'f_pricing_flag', 'po_req_disp', 'site_pick_slip_req', 'ret_prc_req', 'rg_skid_rounding_flag', 'gs_fuel_zone', 'hba_gm_disc_overide', 'gs_frz_rbt_flag', 'store_name', 'swell', 'finance_charge_effective_date', 'gs_portal_folder_nbr', 'statement_address1', 'serv_charge', 'store_group_name', 'store_bill_to_flag', 'sales_representative', 'gs_dash_9_description', 'delinquent_start_date', 'statement_state', 'store_province', 'confo', 'tax_exempt', 'awi_customer_type', 'bb_mod_program', 'store_address1', 'rej_reason', 'store_postal_code', 'small_pack', 'acct_type', 'gs_dash_2_description', 'payment_grace_days', 'chain_inactive_date', 'gs_nabisco', 'catalog10', 'location_id', 'acct_cust_class_code', 'gs_tpr_group', 'cm_payment_ ...

# %%
import cx_Oracle
import pandas as pd
import numpy as np
from Utils.queries import Merge_TRX, curr_gtt_query, audit_insert
from Utils.sql_callables import execute_sql_on_db

cx_Oracle.init_oracle_client(lib_dir="C://Users//User//Downloads//instantclient-basic-windows.x64-21.10.0.0.0dbru//instantclient_21_10")

try:
    source_conn = cx_Oracle.connect(
        user="apps",
        password="apps",
        dsn="csebsd2db.cswg.com:1521/csebsd2_int"
    )
    cursor = source_conn.cursor()

    print('Start of Process to get changes from the cur_gtt')
    # ... (rest of your code)
    try:
        for index, row in cur_gtt.iterrows():
            # Construct the dynamic update query
            update_query = f"""
                UPDATE xxfin.xxar_customer_master a
                SET {', '.join([f"a.{column} = '{row[column]}'" for column in cur_gtt.columns])}
                WHERE party_site_id = {row['PARTY_SITE_ID']}
            """
            # Execute the update query
            cursor.execute(update_query)
            # Get the number of rows affected
            rows_updated = cursor.rowcount

            # Print the number of rows updated
            print(f"Rows updated: {rows_updated}")

            # Commit the changes
            source_conn.commit()

    except cx_Oracle.DatabaseError as e:
        # If an error occurs, print the error message
        print(f"Error: {e}")

finally:
    # Close the cursor and connection
    if 'cursor' in locals() and cursor is not None:
        cursor.close()
    if 'source_conn' in locals() and source_conn is not None:
        source_conn.close()
