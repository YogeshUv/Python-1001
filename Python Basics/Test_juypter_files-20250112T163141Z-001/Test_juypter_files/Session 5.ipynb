# %%
num = 1000
num
# Out:
# 1000

# %%
nifty = 19688
gap = 1.02
up = nifty * gap
up
# Out:
# 20081.760000000002

# %%
gap = 0.98
down = nifty * (gap)
down
# Out:
# 19294.239999999998

# %%
type(num)
# Out:
# int

# %%
a = float(num)
type(a)
# Out:
# float

# %%
b = complex(num,5)
b
# Out:
# (1000+5j)

# %%
str_num= str(num)
str_num
# Out:
# '1000'

# %%
c =complex(str_num,b)
c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-9ec03cbf8f03> in <module>
# ----> 1 c =complex(str_num,b)
#       2 c
#
# TypeError: complex() can't take second arg if first is a string

# %%
d = bool(-9)
d
# Out:
# True

# %% [markdown]
# # **Other than zero everything is True, zero is False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
float_number = 3.14
str_float = complex(float_number)
print(str_float)
# Out:
# (3.14+0j)
