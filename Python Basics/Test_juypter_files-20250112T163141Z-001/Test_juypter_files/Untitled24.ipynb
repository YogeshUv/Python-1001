# %%
#testing for 100 rows
import cx_Oracle
import pandas as pd
import os
# import pyarrow.parquet as pq
# Source database connection
source_conn = cx_Oracle.connect(
    user="apps",
    password="apps",
    dsn="csebsd2db.cswg.com:1521/csebsd2_int"
)
source_cursor = source_conn.cursor()
TRX_query = """SELECT
          TRX_DATE, SHIP_TO_SITE_USE_ID
    FROM APPS.RA_CUSTOMER_TRX_ALL WHERE ROWNUM <= 100"""
# %%time
source_cursor.execute(TRX_query)
TRX_df = source_cursor.fetchall()
TRX_df
# Out:
# [(datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 12, 0, 0), 14837),
#  (datetime.datetime(2013, 8, 31, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 26, 0, 0), 14837),
#  (datetime.datetime(2013, 10, 19, 0, 0), 14837)]
