# %%
class Cat():
  pass

# %%
class Animal():
  def __init__(self,eats,sleeps):
    self.eats = eats
    self.sleeps = sleeps

# %%
a = Animal('food',10)
type(a)
# Out:
# __main__.Animal

# %%
a.eats
# Out:
# 'food'

# %%
a.sleeps
# Out:
# 10
