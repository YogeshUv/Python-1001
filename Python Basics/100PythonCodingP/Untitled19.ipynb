# %%
def is_prime(n):
  for i in range(1,n):
    # print(i)
    for j in range(2,int(i**0.5)):
      print('i',i,'j',j)
      if i % j == 0:
        return False
  return True

result = is_prime(17)
result
# Out:
# i 2 j 2
# False

# %%
n = 33
def is_prime(n):
  for i in range(2,n):
    for j in range(2,int(n**0.5)+1):
      # print(i,j)
        if i % j ==0:
          return False

        else:
          return True
resu is_prime(n)
# Out:
# False
