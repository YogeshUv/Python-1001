# %%
names = ['yogi','rakz','uv','kd']
age =[27,27,30,12]

# %%
import pandas as pd

# %%
data_file = pd.DataFrame(data=zip(names,age),columns=('names','age'))

# %%
path_str = r'D:\P\PythonDS\\'
path_str = path_str.replace('\\', '\\')
path_str
# Out:
# 'D:\\P\\PythonDS\\\\'

# %%
import os

path_str = 'D:\\P\\PythonDS\\\\'
normalized_path = os.path.normpath(path_str)

print(normalized_path)
# Out:
# D:\P\PythonDS\\

# %%
data_file.to_csv("D:\\P\\PythonDS\\sample.csv")
os.cwd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4c1379bc0482> in <cell line: 2>()
#       1 data_file.to_csv("D:\\P\\PythonDS\\sample.csv")
# ----> 2 os.cwd
#
# AttributeError: module 'os' has no attribute 'cwd'
