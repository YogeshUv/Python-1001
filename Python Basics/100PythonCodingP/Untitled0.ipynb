# %%
1+1
# Out:
# 2

# %%
c = 100 # An integer value assignment
miles = 1000.5 # A floating value assignment
name = "Yogesh" # A String

# %% [markdown]
# print(c)
# print(miles)
# print(name)

# %%
print(type(c))
print(type(miles))
print("The Type of variable name: ",type(name))
# Out:
# <class 'int'>
# <class 'float'>
# The Type of variable name:  <class 'str'>

# %%
name= "Yogesh"
print(name)
print(type(name))
print("The type of the variable is : ",type(name)[7])
# Out:
# Yogesh
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-592b7a94d75c> in <module>()
#       2 print(name)
#       3 print(type(name))
# ----> 4 print("The type of the variable is : ",type(name)[7])
#
# TypeError: 'type' object is not subscriptable

# %%
a = b = c =11
print("The value of a is ",a,"the value of b is",b,c)
print(id(a),id(b),id(c))
# Out:
# The value of a is  11 the value of b is 11 11
# 11256384 11256384 11256384

# %% [markdown]
# Standard data types
# Number String List tuple Dictionary

# %%
a = "ks "
print(  (a+" ")* 5 )
# Out:
# ks  ks  ks  ks  ks

# %%
first_name='Yogesh'
last_name='KS'
print(first_name[0]);print(last_name[0])
print(first_name[0],last_name[0])
ba=first_name[0],last_name[0]
print(ba)
print(len(ba))
# Out:
# Y
# K
# Y K
# ('Y', 'K')
# 2

# %%
str1 = 'Yogesh'
print(str1[-3::-1])
# Out:
# ego

# %%
all_lang=['java','python','C#','JS','C++','C']
print(all_lang[3::-1])
lang_learnt=['java','C#']
print(lang_learnt)
# Out:
# ['JS', 'C#', 'python', 'java']
# ['java', 'C#']

# %%
num ='1234567890'
print(num[1::2]) #even numbers
print(num[::2])  #odd numbers
# Out:
# 24680
# 13579

# %%
tuple1 =('a','b','c','e','d','h','g')
print(tuple1)
print(tuple1[2:5])
print(tuple1+tuple1*5) #6 times so BODMAS fowllowed
# Out:
# ('a', 'b', 'c', 'e', 'd', 'h', 'g')
# ('c', 'e', 'd')
# ('a', 'b', 'c', 'e', 'd', 'h', 'g', 'a', 'b', 'c', 'e', 'd', 'h', 'g', 'a', 'b', 'c', 'e', 'd', 'h', 'g', 'a', 'b', 'c', 'e', 'd', 'h', 'g', 'a', 'b', 'c', 'e', 'd', 'h', 'g', 'a', 'b', 'c', 'e', 'd', 'h', 'g')

# %%
dic = {}
print(dic)
dic['Good']= "shubha"
dic['night']= 'ratri'
print(dic)
# Out:
# {}
# {'Good': 'shubha', 'night': 'ratri'}

# %% [markdown]
# Dict with programming languages and expertise as the values

# %%
prog= {'Java':'5','C#':4,'python':3}
print(prog)
print(prog['Java'])
prog ={'MySQL':5}
prog['SQL'] =3
# Out:
# {'Java': '5', 'C#': 4, 'python': 3}
# 5

# %%
print(prog)
# Out:
# {'MySQL': 5}

# %%
prog= {'Java':'5','C#':4,'python':3}

# %%
prog['SQL'] =3

# %%
print(prog)
# Out:
# {'Java': '5', 'C#': 4, 'python': 3, 'SQL': 3}

# %%
print("enter a number between 1-10")
b= input()
c= b+1
print(b)
print(c)
# Out:
# enter a number between 1-10
# 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-a0524b68f2c0> in <module>()
#       1 print("enter a number between 1-10")
#       2 b= input()
# ----> 3 c= b+1
#       4 print(b)
#       5 print(c)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = 1500; b = 0.04;

# %%
a=1500
b=0.04
print(a*b)
# Out:
# 60.0

# %%
#Comparition Operator
apple =0
print(apple==a)
print(a)
print(apple)
# Out:
# False
# 1500
# 0

# %%
c = a *b
c /=100
c *=100
c+=10
c-=20
print(c)
# Out:
# 50.0

# %%
print(False or False)
print(False and False)
print(not((False or False)))
print(not(False and False))
# Out:
# False
# False
# True
# True

# %%
print(all_lang)
print('C' in all_lang) #Concept not working. 
# is is identity operator which checks for id
# in is checking list
# Out:
# ['java', 'python', 'C#', 'JS', 'C++', 'C']
# True
