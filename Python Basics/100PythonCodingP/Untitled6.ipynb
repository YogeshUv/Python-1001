# %%
print("Google"[1])
# Out:
# o

# %%
for i in "Google":
  print(i,end="")
# Out:
# Google

# %%
print("123"+"456")
# Out:
# 123456

# %%
print(123+int("456"))
# Out:
# 579

# %%
Hello="World"
print(Hello[4]+Hello[2])
# Out:
# dr

# %%
print(len(234))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-b2cb913a0595> in <module>()
# ----> 1 print(len(234))
#
# TypeError: object of type 'int' has no len()

# %%
print("a",5,"b",end="")
# Out:
# a 5 b

# %%
c= str(5)
print("a"+c+"b")
# Out:
# a5b

# %%
a=100+float(50)
print(a)
print(type(a))
# Out:
# 150.0
# <class 'float'>

# %%
print(str(70)+str(100))
# Out:
# 70100

# %%
num = input("enter the number--")
sum = int(num[0])+int(num[1])
print(sum)
# Out:
# enter the number--25
# 7

# %%
print(6/3)

# %%
print(5**2)

# %%
weight =float(input("Enter your weight?--"))
height =float(input("Enter your height?--"))

bmi= weight/height**2

print(int(bmi))
# Out:
# Enter your weight?--65
# Enter your height?--2
# 16

# %%
print(8/3)
# Out:
# 2.6666666666666665

# %%
print(int(8/3))
# Out:
# 2

# %%
print(round((8/3),2))
# Out:
# 2.67

# %%
print(8//3)
# Out:
# 2

# %%
print(type(8/4))
# Out:
# <class 'float'>

# %%
#short hand
score=0
score+=1
print(score)
# Out:
# 1

# %%
score  =7
height=1.8
isWinning = True
#f-string
print(f"YOu got a score of {score} and your height is {height} you are winning is {isWinning}")
# Out:
# YOu got a score of 7 and your height is 1.8 you are winning is True

# %%
age= input("what is your age?_-")
age_as_int = int(age)
age_left = 90-age_as_int
days_left =age_left*365
week_left = age_left*52
months_left = age_left*12
message  = f"You have {days_left} many days left {week_left}  weeks left and {months_left} months left , just {age_left} years left to live"
print(message)
# Out:
# what is your age?_-26
# You have 23360 many days left 3328  weeks left and 768 months left , just 64 years left to live
