# %%
What is Genarative AI
Applications of Generative AI
Examples of Genrative AI
WHat are LLMs
Google - Gemini AI
Hands on Gemini AI application in UI mode
Hands on Gemini AI using Python
Creatting strem lit applications Using Python
# Out:
#   File "<ipython-input-1-5ec3889e406c>", line 1
#     What is Genarative AI
#                        ^
# SyntaxError: invalid syntax

# %%
JObs wont go more jobs will be there we will be fast update.
Prompt Engineering.


Models
Machine Learning
we are passing a data to the machine the machine try to understand the data,
when you send unknow data still it understand

Models of ALgorithms
Machine learning algrithms
Machine Learning models

Large language model

ChatGpt - OpenAI + Microsoft

Goolge Brad model --->
Google Gemini

# %%
google ai studio

# %%
api_key = 'AIzaSyBpgKhjDBHdcKq_b2jJphGCFkplmoBdsSQ'

# %%
# !pip install google-generativeai
# install the package

# %%
import os
import google.generativeai as genai
api_key = "AIzaSyBpgKhjDBHdcKq_b2jJphGCFkplmoBdsSQ"
genai.configure(api_key=api_key)

#we are accesing goggle gemini model
# with our api key

# %%
for i in genai.list_models():
  print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision
# models/embedding-001
# models/aqa

# %%
project_id = "Yogeshyouwe"

# %%
# !gcloud auth application-default login --scopes=https://www.googleapis.com/auth/cloud-platform
# Out:
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fapplicationdefaultauthcode.html&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform&state=IHCAsNc5C4GNypWR0eq5uMj12a6bA5&prompt=consent&token_usage=remote&access_type=offline&code_challenge=aqMpY_S2zS9EYS9eHQR7nMGQ06t75Zxdqjnq0Lb2zC0&code_challenge_method=S256
#
# Enter authorization code: 4/0AeaYSHBkh76o-gw74Kq3nqyIMBJo037gn8lmTwn7txu4cS7HmZ2BYHD1AJ7A2ndgjrXC7g
#
# Credentials saved to file: [/content/.config/application_default_credentials.json]
#
# These credentials will be used by any library that requests Application Default Credentials (ADC).
# WARNING:
# ...

# %%
genai.set_project_id(project_id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-efb193606396> in <cell line: 1>()
# ----> 1 genai.set_project_id(project_id)
#
# AttributeError: module 'google.generativeai' has no attribute 'set_project_id'

# %%
model = genai.GenerativeModel('genini-pro')
model
# Out:
#  genai.GenerativeModel(
#    model_name='models/genini-pro',
#    generation_config={}.
#    safety_settings={}
# )

# %%
response = model.generate_content('Top 5 indian cricketer')
print(response.text)
# Out:
# WARNING:tornado.access:404 POST /v1beta/models/genini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 2411.54ms
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-22-73385bba0b49> in <cell line: 1>()
# ----> 1 response = model.generate_content('Top 5 indian cricketer')
#       2 print(response.text)
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, **kwargs)
#     246             return generation_types.GenerateContentResponse.from_iterator(iterator)
#     247         else:
# --> 248             response = self._client.generate_content(request)
#     249             return generation_types.GenerateContentResponse.from_response(response)
#     250
#
# ...

# %%
from PIL import Image
img = Image.open("/content/image (13).png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1519x478>

# %%
import os
import google.generativeai as genai
api_key = "AIzaSyBpgKhjDBHdcKq_b2jJphGCFkplmoBdsSQ"
genai.configure(api_key=api_key)
model = genai.GenerativeModel("models/gemini-1.0-pro-vision-latest")
model
prompt = "What are the words in the given image"
response = model.generate_content([prompt,img])
response.text
# Out:
# ' C1\nMy 100 Vendors\nC2\nVendors with FL = 1 or 2 or FREIGHT = Y or HOME = 21\nC3\nALL Active facilities have the condition to excule the parent facility.\nOpen C2\nOpen C3 with C2 Facility Passing.\nLoop\nClone the Vendors to all Cursor CLONE VENDORS\nEnd Loop\nEnd C2\n92 Facilities\nWill come from C3'

# %%
pip install streamlit

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 0.416s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 2 moderate severity vulnerabilities
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai
from PIL import Image

api_key = "AIzaSyBpgKhjDBHdcKq_b2jJphGCFkplmoBdsSQ"
genai.configure(api_key=api_key)

st.header("Image analytics")

uploaded_file = st.file_uploader("Upload an image", type= ["png","jpg","jpeg"])

if uploaded_file is not None:
  st.image(Image.open(uploaded_file))

prompt = st.text_input("Enter the text")

if st.button("GET RESPONSE"):
  img = Image.open(uploaded_file)
  model = genai.GenerativeModel("models/gemini-1.0-pro-vision-latest")
  response = model.generate_content([prompt,img])
  st.markdown(response.text)
# Out:
# Overwriting app.py

# %%
# !streamlit run /content/app.py & npx localtunnel --port 7777 & curl ipv4.icanhazip.com
# Out:
# 34.125.15.118
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.15.118:8501
#
# npx: installed 22 in 2.315s
# your url is: https://free-tools-divide.loca.lt

# %%
# !npm install -g localtunnel
# Out:
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# added 22 packages from 22 contributors in 0.664s

# %%
# !lt --port 8000
# Out:
# your url is: https://ready-clouds-fly.loca.lt
# /tools/node/lib/node_modules/localtunnel/bin/lt.js:81
#     throw err;
#     ^
#
# Error: connection refused: localtunnel.me:37721 (check your firewall settings)
#     at Socket.<anonymous> (/tools/node/lib/node_modules/localtunnel/lib/TunnelCluster.js:52:11)
#     at Socket.emit (events.js:315:20)
#     at emitErrorNT (internal/streams/destroy.js:106:8)
#     at emitErrorCloseNT (internal/streams/destroy.js:74:3)
#     at processTicksAndRejections (internal/process/task_queues.js:80:21)
