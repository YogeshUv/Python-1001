# %%
s = 'The NIFTY 50 is a benchmark Indian stock market index that represents the weighted average of 50 of the largest Indian companies listed the National Stock Exchange. It is one of the two main stock indices used in India, the other being the BSE SENSEX. Wikipedia'
l =s.split(',','.')
print((l))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ef17cfa8e3ac> in <module>()
#       1 s = 'The NIFTY 50 is a benchmark Indian stock market index that represents the weighted average of 50 of the largest Indian companies listed the National Stock Exchange. It is one of the two main stock indices used in India, the other being the BSE SENSEX. Wikipedia'
# ----> 2 l =s.split(',','.')
#       3 print((l))
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
lists = [[],[],[]]
lists2=[[]]
list3=lists2*3

list3[0].append(3)
print(list3)
# Out:
# [[3], [3], [3]]

# %%
d ={}
l1 =['a','b','c']
l2 =[1,2,3]
d = dict(zip(l1,l2))
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
# sets
s = {1,2,3,3,3,32,23,3,3,3,4,5,6}
s
type(s)
# Out:
# set

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 23, 32}

# %%
s2 = {1,2,3,3,4,5,6,676,54,5,535,3265524,4,4,}

# %%
s1=set()
print(s.union(s2))
# Out:
# {32, 1, 2, 3, 4, 5, 6, 676, 535, 3265524, 54, 23}

# %%
s.intersection(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s2.difference(s)
# Out:
# {54, 535, 676, 3265524}

# %%
def factorial(n):
  if n ==1:
    return 1
  else:
    return n * factorial(n-1)
print(factorial(5))
# Out:
# 120
