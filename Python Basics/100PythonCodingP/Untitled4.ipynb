# %%
from collections import deque
 
stack = deque()
arr = "{}{}{}{"
# append() function to push
# element in the stack

for i in arr:
  .append('a')

 
print('Initial stack:')
print(stack)
 
# pop() function to pop
# element from stack in
# LIFO order
print('\nElements popped from stack:')
print(stack.pop())
print(stack.pop())
print(stack.pop())
 
print('\nStack after elements are popped:')
print(stack)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-6e9684148a5c> in <module>()
#       7
#       8 for i in arr:
# ----> 9   arr.append('a')
#      10
#      11
#
# AttributeError: 'str' object has no attribute 'append'

# %%
#1. Taking input from the User
test_string = input("Enter the Combination of '{' and '}' to check -- ")
#2. 
# using list()
# for splitting string to list of characters
res = list(test_string)
# printing result
res.append('}')
print(res)
# print ("Taking the input in a list " +  str(res))
# Out:
# Enter the Combination of '{' and '}' to check -- {}{{}{
# ['{', '}', '{', '{', '}', '{', '}']

# %%
# Stack implementation in python


# Creating a stack
def create_stack():
    stack = []
    print(type(stack))
    return stack

create_stack()
# Out:
# <class 'list'>
# []

# %%
# Stack implementation in python


# Creating a stack
def create_stack():
    stack = []
    return stack


# Creating an empty stack
def is_empty(stack):
    return len(stack) == 0


# Adding items into the stack
def push(stack, item):
    stack.append(item)
    print("pushed item: " + item)


# Removing an element from the stack
def pop(stack):
    if (is_empty(stack)):
        return "stack is empty"

    return stack.pop()


#1. Taking input from the User
test_string = input("Enter the Combination of '{' and '}' to check -- ")
#2. 
# using list()
# for splitting string to list of characters
res = list(test_string)
print(res)
print(len(res))


stack = create_stack()
print(stack)
print(type(stack))
for i in range(len(res)):
  push(stack, res[i])
a = []
push(a,'+')
print(a)
# for i in range(len())
print("popped item: " + pop(stack))
print("stack after popping an element: " + str(stack))
# Out:
# Enter the Combination of '{' and '}' to check -- {}{}{}
# ['{', '}', '{', '}', '{', '}']
# 6
# []
# <class 'list'>
# pushed item: {
# pushed item: }
# pushed item: {
# pushed item: }
# pushed item: {
# pushed item: }
# pushed item: +
# ['+']
# popped item: }
# stack after popping an element: ['{', '}', '{', '}', '{']

# %%
#1.Take a input from the user using input().
test_string = input("Enter the Combination of brackets")
Ques = list(test_string)
check =[]
print(Ques)
for i in Ques:
  push(check,i)
  print(check)
  print(len(check))
  while len(check)>=2:
    for i in range(1,len(check)):
      # print(i)
      # print(len(check))
      while check[0]=='}' and check[1]=='{':
        pop(check)
        pop(check)
    
print(check)
# Out:
# ['{', '}', '{', '}', '{', '}']
# pushed item: {
# ['{']
# 1
# pushed item: }
# ['{', '}']
# 2

# %%
a = ['{', '}', '{', '}}']
for i in reversed(a):
     print(i)
# Out:
# }}
# {
# }
# {

# %%
a = ['{', '}', '{', '}']
print(a)
def check():
  for i in range(len(a)-2, 0, -1):
    a.append('+')
    if a[len(a)-1]=='{':
      print("Invalid Combination cant end with '{'")
      break
    if a[0]=='}':
      print("Invalid Combination first cant be '}'")
      break
      print(a[i])
    if a[i+1]=='}' and a[i]=='{':
        print('cool')
        pop(a)
        pop(a)
        print(a)
        check()
check()
# Out:
# ['{', '}', '{', '}']
# cool
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-1bafffd51f7d> in <module>()
#      17         print(a)
#      18         check()
# ---> 19 check()
#
# <ipython-input-54-1bafffd51f7d> in check()
#      13     if a[i+1]=='}' and a[i]=='{':
#      14         print('cool')
# ---> 15         pop(a-1)
#      16         pop(a-1)
#      17         print(a)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
def check(my_string):
    brackets = '{}'
    while any(x in my_string for x in brackets):
        for br in brackets:
            my_string = my_string.replace(br, '')
    return not my_string
   
# Driver code
string = "}{{}{{}{}{{{}}}}"
if check(string):
  print(string, "-", "Balanced")
else:
  print(string, "-", "UnBalanced")
# Out:
# }{{}{{}{}{{{}}}} - Balanced

# %%
def check(my_string):
    brackets = '{}'
    while any(x in my_string for x in brackets):
        for br in brackets:
            my_string = my_string.replace(br, '')
    return not my_string
   
# Driver code
string = "{{}{}{}{{{}}}}"
if check(string):

print(string, "-", "Balanced" if check(string) else "Unbalanced")
# Out:
# }}{{}{}{}{{{}}}} - Balanced

# %%
def check(my_string):
    brackets = ['{}']
    # while any(x in my_string for x in brackets):
    for br in brackets:
        my_string = my_string.replace(br, '')
        # print(my_string)
        check(my_string)
    return not my_string
   
# Driver code
string = "{{{}{}}}}}"
# print(my_string)
print(string)
print(string, "-", "Balanced" if check(string) else "Unbalanced")
# Out:
# {{{}{}}}}}
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-85-100826ae15d9> in <module>()
#      13 # print(my_string)
#      14 print(string)
# ---> 15 print(string, "-", "Balanced" if check(string) else "Unbalanced")
#
# <ipython-input-85-100826ae15d9> in check(my_string)
#       6         my_string = my_string.replace(br, '')
#       7         # print(my_string)
# ----> 8         check(my_string)
#       9     return not my_string
#      10
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-85-100826ae15d9> in check(my_string)
#       6         my_string = my_string.replace(br, '')
#       7         # print(my_string)
# ----> 8         check(my_string)
#       9     return not my_string
#      10
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
