# %%
lst = [2,2,3]
sum =0
for i in lst:
  sum = sum + i
print(sum)
# Out:
# 7

# %%
# Write a program if two unordered list contain exact similar elements in exact similar positions, i.e to check if two lists are exactly equal.

lst1=[1,2,3]
lst2=[1,2,4]
if lst1 == lst2:
  print("True")
else:
  print("False")
# Out:
# False

# %%
# write a Python program to check if all the elements in that list are identical.
lst3 =[2,2,2,2,2,2]
if len (set(lst3))==1:
  print(' Its Identical')
else:print('Its Not identical')
# Out:
# identical

# %%
my_list = [1,2,3]
for num in range()
