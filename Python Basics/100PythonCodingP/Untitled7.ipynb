# %%
s="apple"

# %%
print(s[3:2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-81c5f290379e> in <module>()
# ----> 1 print(s[3:2])
#
# NameError: name 's' is not defined

# %%
x = input()
match x:
  case "hi" | "bye":
    print("1")
