# %%
var i = 0;
	while(i<=20){
		console.log("The Counter is : ", i);
		i = i + 2;
	}
	
	console.log("\n")
	console.log("---------------------")
	console.log("\n")
# Out:
#   File "<ipython-input-1-edf9488c4465>", line 1
#     var i = 0;
#         ^
# SyntaxError: invalid syntax

# %%
var counter = 1;
	while(counter <=10){
		console.log("The counter is , " , counter);
		counter++;
	}
# Out:
#   File "<ipython-input-2-d27912d5815c>", line 1
#     var counter = 1;
#               ^
# SyntaxError: invalid syntax
